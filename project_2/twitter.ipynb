# %%
# !pip install python-twitter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 67 kB 2.6 MB/s
# ...

# %%
twitter_consumer_key = "KVbJZSmL7j34kYd8thYIJh1kc"
twitter_consumer_secret = "6bbbbvA60H5Zb50ItBaboxqC3K3HllGBlgVXiIjT32PAJJpXPW"  
twitter_access_token = "1457668604670152704-dOlNDuEsxFtgcDyU6mldZyxqq0WOOt"
twitter_access_secret = "9Ly17RLUYlUZ3CIq0zPh66NUJK29bzOQhweOYUixIs3Fw"

import twitter

twitter_api = twitter.Api(consumer_key=twitter_consumer_key,
                          consumer_secret=twitter_consumer_secret, 
                          access_token_key=twitter_access_token, 
                          access_token_secret=twitter_access_secret)

# %%
account = "@TheBlueHouseKR"
statuses = twitter_api.GetUserTimeline(screen_name=account, count=200, include_rts=True, exclude_replies=False)
print(statuses)
# Out:
# [Status(ID=1523604490389450753, ScreenName=TheBlueHouseKR, Created=Mon May 09 10:03:12 +0000 2022, Text='문재인 대통령이 제19대 대한민국 대통령으로서 국민께 마지막 편지를 보냅니다. 문 대통령의 편지를 영상으로 전해 드립니다. https://t.co/nen7vLa0g0'), Status(ID=1523582867103617024, ScreenName=TheBlueHouseKR, Created=Mon May 09 08:37:16 +0000 2022, Text='[LIVE] 문재인 대통령의 퇴근길\n오후 6시 청와대를 나서는 문재인 대통령의 모습을 라이브로 전해 드립니다.\n문 대통령은 집무실을 나선 뒤 김정숙 여사와 관저에서 출발해 본관을 거쳐 사랑채로 이동합니다.… https://t.co/uRbnbd87Ls'), Status(ID=1523580245118386176, ScreenName=TheBlueHouseKR, Created=Mon May 09 08:26:51 +0000 2022, Text='왕 부주석은 문재인 대통령이 한중관계 발전에 많은 기여를 해 주신 데 대해 중국을 대표해 감사의 뜻을 표하고, 시진핑 국가 주석의 각별한 안부를 전했습니다. 왕 부주석은 문 대통령 내외에게 중국에 언제든지… https://t.co/SoUVOrtWcb'), Status(ID=1523580235106578432, ScreenName=TheBlueHouseKR, Created=Mon May 09 08:26:49 +0000 2022, Text='왕 부주석은 문 대통령이 화해와 협력으로 남북관계 개선에 중요한 기여를 한 것을 높이 평가하며, "중국은 한반도 비핵화를 위해 함께 힘을 기울일 것"이라고 말했습니다. 이어 "중국은 한국과 전략적 협력 동반… https://t.co/V3jgFBeafZ'), Status(ID=1523580224822079488, ScreenName=TheBlueHous
# ...

# %%
query = "renewable energy"
statuses = twitter_api.GetSearch(term=query, count=10000)
for status in statuses:
    print(status.text)
# Out:
# The trains in the Netherlands are 100% #windpowered. Over 5,500 trips a day 100% #renewable.
#
# We have the solutions… https://t.co/HwO68PNTTU
# The Senate CHIPS bill will rebuild our semiconductor chip industry, increase funding for the National Science Found… https://t.co/NXi5r6uDFb
# The sun and wind don’t send a bill.
#
# Renewable energy is the cheapest energy.
#
# The Albanese Government is getting… https://t.co/R5HQhgoJC3
# RT @airnewsalerts: #Ladakh: A two-day training programme on Renewable Energy and Climate Change concluded at Conference Hall of Council Sec…
# Citicore Renewable Energy Co. (CREC) secured a 1MW long-term power supply contract with water management solutions… https://t.co/LElrtomXbW
# RT @crampell: “We’ve got twice the solar we had last summer, and something like three times what we had eighteen months ago,” energy consul…
# RT @saaaauuull: New: @CoriBush has added ANOTHER $5M for renewable energy in the Defense Production Act to the proposed house budget.
# ...

# %%
from collections import Counter
query = "신재생에너지"
statuses = twitter_api.GetSearch(term=query, count=10000)
result = []
for status in statuses:
    for tag in status.hashtags:
        result.append(tag.text)
        
Counter(result).most_common(20)
# Out:
# [('신재생에너지', 4),
#  ('KBS', 3),
#  ('KBS뉴스', 3),
#  ('태양광', 2),
#  ('태양광파랑박사', 2),
#  ('유튜브', 2),
#  ('한국형FIT', 2),
#  ('종합병원', 2),
#  ('에너지다소비', 2),
#  ('저탄소건물', 2),
#  ('삼성서울병원', 2),
#  ('아산병원', 2),
#  ('서울대학병원', 2),
#  ('모래', 2),
#  ('배터리', 2),
#  ('한국기후환경네트워크', 2),
#  ('탄소중립', 2),
#  ('탄소중립생활실천', 2),
#  ('친환경', 2),
#  ('에너지', 2)]

# %%
import tweepy
import config
import pandas as pd


# 트위터 Application에서 발급 받은 key 정보들 문자열로 입력
consumer_key = config.twitter_consumer_key
consumer_secret = config.twitter_consumer_secret
access_token = config.twitter_access_token
access_token_secret = config.twitter_access_secret

# 1. 핸들러 생성 및 개인정보 인증요청
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# 2. 액세스 요청
auth.set_access_token(access_token, access_token_secret)

# 3. twitter API 생성
api = tweepy.API(auth)

keyword = '아동학대예방교육'  # 검색하고 싶은 키워드 입력
result = []  # 크롤링 텍스트를 저장 할 리스트 변수

for i in range(1, 3):  # 1,2 페이지 크롤링
    tweets = api.search(keyword)  # keyword 검색 실시. 결과가 tweets 변수에 담긴다.
    result = []
    for tweet in tweets:
        result.append([tweet.created_at, tweet.id_str, tweet.text, tweet.favorite_count, tweet.retweet_count])
    result = sorted(result, key=lambda x : -x[-2]) # 좋아요 수 기준으로 정렬
df = pd.DataFrame(result, columns = ['time', 'id', 'text', 'likey', 'retweet'])
print(len(result))  # 크롤링하여 가져온 트윗 개수
print(df)  # 크롤링 결과 확인
df.to_csv('result.csv', encoding='utf-8-sig')

# %%
# !pip3 install twitter_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 128 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 83 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 112 kB 22.1 MB/s
# ...
#      |████████████████████████████████| 127 kB 45.5 MB/s
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=5bf8c0e3e45171bd895b8795924ec52d9c2a8f01f0b09c102998bee335308a06
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=be6d3ef9d9c2d08fe69ef9c3ac4dfd6f0dd57b95de40c51c9059cc25420364d6
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# Successfully built fake-useragent parse
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
# ...
